# %% [markdown]
# # Mapping and unsupervised clustering analysis for NI tests

# %% [markdown]
# ### Requirements and dependencies

# %%
import sys
import os

module_path = os.path.abspath(os.path.join('..','..'))
if module_path not in sys.path:
    sys.path.append(module_path)
from pathlib import Path

import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import numpy as np
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.mixture import GaussianMixture
from sklearn.cluster import DBSCAN
from kneed import KneeLocator

from Mapping import plot_pdf_with_deconvolution_on_axis
from Mapping import plot_cdf_with_weibull_fit_on_axis
from Mapping import plot_clustered_data
from Mapping import plot_map
from Mapping import plot_pixel_map

from Processing import compute_kam

# Graphics settings
xDim = 4
yDim = 2
cMap = 'viridis'

# %% [markdown]
# ### Specimen informations + Results path + Clustering method

# %%
# Sample 1
sampleNames = ['Synthetic_MatrixFibers']
file_paths = [Path("Dataset/MatrixFibers/synthetic_composite_data_ratio_E_3.xlsx")] # E_matrix / E_fiber = 3 and same similar hardness
#file_paths = [Path("Dataset/MatrixFibers/synthetic_composite_data_ratio_E_1.5.xlsx")] # E_matrix / E_fiber = 1.5 and similar hardness
#file_paths = [Path("Dataset/MatrixFibers/synthetic_composite_data_ratio_E_1.2.xlsx")] # E_matrix / E_fiber = 1.2 and similar hardness
sheet_name = 'Sheet1'

# Sample 2
# sampleNames = ['Ni_SiC']
# file_paths = [Path("Dataset/Ni_SiC/MTS_example1_25x25.xls")]
# file_paths = [Path("Dataset/Ni_SiC/MTS_example1_25x25.xls_interp_81x81.xls")] # To check effect of mapping resolution (artifically interpolated)
# sheet_name = 'Sample'

# Sample 3
# sampleNames = ['HSS-Steel_Carbides']
# file_paths = [Path("Dataset/HSS_Steel_Carbides/MTS_example1_25x25_flower.xls")]
# sheet_name = 'Sample'

# Sample 4
# sampleNames = ['Matrix-Particles']
# file_paths = [Path("Dataset/MatrixParticles/synthetic_composite_data_Particle2MatrixRatio_13%.xlsx")]
# sheet_name = 'Sheet1'

# Create the directory if it doesn't exist using sample name
result_dir = Path("Results/Clustering/" + sampleNames[0])
result_dir.mkdir(parents=True, exist_ok=True)

# %%
# Cluster the data using KMeans, or GMM...
method = 'KMeans'
#method = 'GMM'
#method = 'DBSCAN'

# %% [markdown]
# ### Loading dataset and make mechanical properties dataframe

# %%
# Import data from Excel files
data_frames = []
for file_path in file_paths:
    df = pd.read_excel(file_path, sheet_name=sheet_name)
    data_frames.append(df)
data = pd.concat(data_frames, ignore_index=True)

# Merge first row (containing units) with the header
data.columns = [f"{col}_{unit}" if unit else col for col, unit in zip(data.columns, data.iloc[0])]
data = data.drop(index=0).reset_index(drop=True)
data = data.apply(pd.to_numeric, errors='ignore')

# Replace empty strings with NaN
data.replace("", np.nan, inplace=True)

# Remove colums Markers and Index Integer
data.drop(columns=[col for col in data.columns if 'Markers_nan' in col or 'Index_Integer' in col], inplace=True)
data.drop(columns=[col for col in data.columns if 'Markers' in col], inplace=True)

# Add H/E ratio column if not present
if 'HARDNESS_GPa' in data.columns and 'MODULUS_GPa' in data.columns and 'H/E_ratio' not in data.columns:
    data['H/E_ratio'] = data['HARDNESS_GPa'] / data['MODULUS_GPa']
# Add H^3/E^2 ratio column if not present
if 'HARDNESS_GPa' in data.columns and 'MODULUS_GPa' in data.columns and 'H^3/E^2_ratio' not in data.columns:
    data['H^3/E^2_ratio'] = (data['HARDNESS_GPa'] ** 3) / (data['MODULUS_GPa'] ** 2)

print(data.head())

# Save as a .csv file in 'Results' folder
data.to_csv(result_dir / 'imported_data.csv', index=False)
print(f"Data saved to {result_dir / 'imported_data.csv'}")
# Out:
#    X Position_µm  Y Position_µm  MODULUS_GPa  HARDNESS_GPa  H/E_ratio  \
# 0       0.000000            0.0      224.600        5.3800   0.023954
# 1       0.617284            0.0      222.075        5.0925   0.022931
# 2       1.234568            0.0      219.550        4.8050   0.021886
# 3       1.851852            0.0      217.025        4.5175   0.020816
# 4       2.469136            0.0      214.500        4.2300   0.019720
#
#    H^3/E^2_ratio
# 0       0.003087
# 1       0.002678
# 2       0.002302
# 3       0.001957
# 4       0.001645
# Data saved to Results\3D_Clustering\Ni_SiC\imported_data.csv
# C:\Users\dmercier\AppData\Local\Temp\ipykernel_29112\259734683.py:11: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   data = data.apply(pd.to_numeric, errors='ignore')

# %% [markdown]
# ### Mapping analysis

# %%
# Create a 1x3 subplot layout for H, E and H vs E
fig, axes = plt.subplots(1, 3, figsize=(4*xDim, 2*yDim))

# Plot Hardness map
plot_map(data['X Position_µm'], data['Y Position_µm'], data['HARDNESS_GPa'], 
         title='Hardness (GPa)', xlabel='X Position (µm)', ylabel='Y Position (µm)', 
         logScale=False, ax=axes[0], cmap=cMap)

plot_map(data['X Position_µm'], data['Y Position_µm'], data['MODULUS_GPa'], 
         title='Modulus Map (GPa)', xlabel='X Position (µm)', ylabel='Y Position (µm)', 
         logScale=False, ax=axes[1], cmap=cMap)

# Plot Modulus vs Hardness
sns.scatterplot(y='MODULUS_GPa', x='HARDNESS_GPa', data=data, ax=axes[2])  # Pass the third subplot axis
axes[2].set_title('Modulus vs Hardness')
axes[2].set_ylabel('Modulus (GPa)')
axes[2].set_xlabel('Hardness (GPa)')

# Adjust layout and save the figure
plt.tight_layout()
plt.savefig(result_dir / 'maps_and_scatter.png')
plt.show()

###################################################################################################################
# Remove rows with non-finite values in H/E_ratio or H^3/E^2_ratio
data = data[np.isfinite(data['H/E_ratio']) & np.isfinite(data['H^3/E^2_ratio'])]
# Remove rows with non-positive values in H/E_ratio or H^3/E^2_ratio
data = data[(data['H/E_ratio'] > 0) & (data['H^3/E^2_ratio'] > 0)]

# Alternatively, replace non-finite values with a default value (e.g., 0)
# data['H/E_ratio'] = data['H/E_ratio'].replace([np.inf, -np.inf], np.nan).fillna(0)
# data['H^3/E^2_ratio'] = data['H^3/E^2_ratio'].replace([np.inf, -np.inf], np.nan).fillna(0)

# Create a 1x2 subplot layout for H/E, H^3/E^2
fig, axes = plt.subplots(1, 2, figsize=(4*xDim, 2*yDim))

# Plot H/E map
plot_map(data['X Position_µm'], data['Y Position_µm'], data['H/E_ratio'],
         title='H/E Ratio', xlabel='X Position (µm)', ylabel='Y Position (µm)',
         logScale=True, ax=axes[0], cmap=cMap)

# Plot H^3/E^2 map
plot_map(data['X Position_µm'], data['Y Position_µm'], data['H^3/E^2_ratio'],
         title='H^3/E^2 Ratio', xlabel='X Position (µm)', ylabel='Y Position (µm)',
         logScale=True, ax=axes[1], cmap=cMap)

# Adjust layout and save the figure
plt.tight_layout()
plt.savefig(result_dir / 'H_E_ratio_maps.png')
plt.show()

###################################################################################################################
# Create a 1x2 subplot layout
fig, axes = plt.subplots(1, 2, figsize=(4*xDim, 2*yDim))

n_componentsVal = 3  # Adjust based on expected number of phases

# Plot PDF and GMM Deconvolution for Hardness
plot_pdf_with_deconvolution_on_axis(data, 'HARDNESS_GPa', n_components=n_componentsVal, ax=axes[0])
# Plot PDF and GMM Deconvolution for Modulus
plot_pdf_with_deconvolution_on_axis(data, 'MODULUS_GPa', n_components=n_componentsVal, ax=axes[1])

# Adjust layout and save the figure
plt.tight_layout()
plt.savefig(result_dir / 'pdf_gmm_deconvolution.png')
plt.show()

# Create a 1x2 subplot layout
fig, axes = plt.subplots(1, 2, figsize=(4*xDim, 2*yDim))

# Plot CDF and Weibull fit for Hardness
try:
    plot_cdf_with_weibull_fit_on_axis(data, 'HARDNESS_GPa', ax=axes[0])
    # Plot CDF and Weibull fit for Modulus
    plot_cdf_with_weibull_fit_on_axis(data, 'MODULUS_GPa', ax=axes[1])
except Exception as e:
    print(f"Error in Weibull fitting: {e}")

# Adjust layout and save the figure
plt.tight_layout()
plt.savefig(result_dir / 'cdf_weibull_fit.png')
plt.show()
# Out:
# c:\Users\dmercier\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\dmercier\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but GaussianMixture was fitted with feature names
#   warnings.warn(
# c:\Users\dmercier\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but GaussianMixture was fitted with feature names
#   warnings.warn(
# c:\Users\dmercier\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\dmercier\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but GaussianMixture was fitted with feature names
#   warnings.warn(
# c:\Users\dmercier\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but GaussianMixture was fitted with feature names
#   warnings.warn(
# Component 1: Shape=4.412, Scale=7.010, Weight=0.440
# Component 2: Shape=12.387, Scale=4.961, Weight=0.515
# Component 1: Shape=1.500, Scale=2.000, Weight=-50.055
# Component 2: Shape=3.000, Scale=5.000, Weight=50.555
# c:\Users\dmercier\OneDrive - ANSYS, Inc\Documents\GitHub\Indentation2025_AnsysWorkshop\Atelier1_ML-Clustering\Mapping.py:75: OptimizeWarning: Covariance of the parameters could not be estimated
#   popt, _ = curve_fit(weibull_mixture, sorted_data, cdf, p0=initial_params)

# %% [markdown]
# ### Adding KAMM values

# %%
# Calculation of KAMM parameter
order = 1  # 1 for first order, 2 for second order

# Estimation of KAMM, KAEM, KAPM, etc.
data = compute_kam(data, result_dir, order)
print(data.head())

# Create a subplot layout
fig, axes = plt.subplots(1, 3, figsize=(4*xDim, 2*yDim))
# Plot KAMM
plot_map(data['X Position_µm'], data['Y Position_µm'], data['KAMM'],
            title='KAMM (GPa²)', xlabel='X Position (µm)', ylabel='Y Position (µm)', 
            logScale=False, ax=axes[0], cmap='magma')  # Pass the first subplot axis
# Plot KAEM for Modulus
plot_map(data['X Position_µm'], data['Y Position_µm'], data['KAEM'], 
         title='KAEM Modulus (GPa)', xlabel='X Position (µm)', ylabel='Y Position (µm)', 
            logScale=False, ax=axes[1], cmap='magma')  # Pass the second subplot axis
# Plot KAPM for Hardness
plot_map(data['X Position_µm'], data['Y Position_µm'], data['KAPM'], 
         title='KAPM Hardness (GPa)', xlabel='X Position (µm)', ylabel='Y Position (µm)', 
            logScale=False, ax=axes[2], cmap='magma')  # Pass the second subplot axis

# Create a subplot layout for KAMM_RATIO and KAMM_NORMPROD
fig, axes = plt.subplots(1, 2, figsize=(3*xDim, 2*yDim))
# Plot KAMM_RATIO
plot_map(data['X Position_µm'], data['Y Position_µm'], data['KAMM_RATIO'],
            title='KAMM RATIO', xlabel='X Position (µm)', ylabel='Y Position (µm)', 
            logScale=True, ax=axes[0], cmap='magma')  # Pass the first subplot axis
# Plot KAMM_NORMPROD
plot_map(data['X Position_µm'], data['Y Position_µm'], data['KAMM_NORMPROD'], 
         title='KAMM NORMPROD', xlabel='X Position (µm)', ylabel='Y Position (µm)', 
            logScale=True, ax=axes[1], cmap='magma')  # Pass the second subplot axis

# Adjust layout and save the figure
plt.tight_layout()
plt.savefig(result_dir / 'kamm_maps.png')
plt.show()
# Out:
# Raw data columns: ['X Position_µm', 'Y Position_µm', 'MODULUS_GPa', 'HARDNESS_GPa', 'H/E_ratio', 'H^3/E^2_ratio']
#    X Position_µm  Y Position_µm  MODULUS_GPa  HARDNESS_GPa  H/E_ratio  \
# 0       0.000000            0.0      224.600        5.3800   0.023954
# 1       0.617284            0.0      222.075        5.0925   0.022931
# 2       1.234568            0.0      219.550        4.8050   0.021886
# 3       1.851852            0.0      217.025        4.5175   0.020816
# 4       2.469136            0.0      214.500        4.2300   0.019720
#
#    H^3/E^2_ratio        KAMM      KAEM      KAPM  KAMM_RATIO  KAMM_NORMPROD
# 0       0.003087   61.953125  1.275000  0.247500    1.770300       1.055280
# 1       0.002678   54.532724  2.066667  0.215625    1.599375       2.011790
# 2       0.002302   58.526406  2.441667  0.212917    1.521239       3.551101
# 3       0.001957   68.969828  2.816667  0.258125    2.109011       5.432620
# 4       0.001645  175.560521  9.916667  0.580000    3.916781      13.027972

# %% [markdown]
# ### Matrix correlation analysis

# %%
# Plot matrix correlation
plt.figure(figsize=(2*xDim, 2*yDim))
sns.heatmap(data.corr(), annot=True, fmt=".2f", cmap='coolwarm', cbar_kws={"shrink": .8})
plt.title('Correlation Matrix')
plt.savefig(result_dir / 'correlation_matrix.png')
plt.show()

# %% [markdown]
# ### Clustering analysis - Number of clusters estimation

# %%
if method == 'KMeans':
    # Determine optimal number of clusters using Elbow Method
    inertia = []
    K = range(1, 10)
    for k in K:
        kmeans = KMeans(n_clusters=k, random_state=42)
        kmeans.fit(data[['HARDNESS_GPa', 'MODULUS_GPa']].dropna())
        inertia.append(kmeans.inertia_)

    # Plot the Elbow Method
    plt.figure(figsize=(2*xDim, 1.5*yDim))
    plt.plot(K, inertia, 'bx-')
    plt.xlabel('Number of clusters')
    plt.ylabel('Inertia')
    plt.title('Elbow Method For Optimal k')
    plt.savefig(result_dir / 'elbow_method.png')
    plt.show()

    # Find the optimal number of clusters using KneeLocator
    knee_locator = KneeLocator(K, inertia, curve="convex", direction="decreasing")
    optimal_k = knee_locator.knee

elif method == 'GMM':
    # Determine optimal number of clusters using BIC
    bics = []
    K = range(1, 10)
    for k in K:
        gmm = GaussianMixture(n_components=k, random_state=42)
        gmm.fit(data[['HARDNESS_GPa', 'MODULUS_GPa']].dropna())
        bics.append(gmm.bic(data[['HARDNESS_GPa', 'MODULUS_GPa']].dropna()))

    # Plot the BIC
    plt.figure(figsize=(2*xDim, 1.5*yDim))
    plt.plot(K, bics, 'bx-')
    plt.xlabel('Number of clusters')
    plt.ylabel('BIC')
    plt.title('BIC For Optimal k')
    plt.savefig(result_dir / 'bic_method.png')
    plt.show()

    # Find the optimal number of clusters using KneeLocator
    knee_locator = KneeLocator(K, bics, curve="convex", direction="increasing")
    optimal_k = knee_locator.knee

elif method == 'DBSCAN':
    optimal_k = None
    
print(f"Optimal number of clusters: {optimal_k}")
#optimal_k = 3  # Manually set for demonstration  or in case of wrong estimation
# Out:
# c:\Users\dmercier\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\dmercier\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\dmercier\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\dmercier\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\dmercier\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\dmercier\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\dmercier\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\dmercier\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\dmercier\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# Optimal number of clusters: 3

# %% [markdown]
# ### Principle component analysis (PCA)

# %%
# Investigate Principle Component Analysis (PCA)
# scikit-learn.org/stable/modules/generated/sklearn.decomposition.PCA.html
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# Standardize the data
features = ['HARDNESS_GPa', 'MODULUS_GPa', 'H/E_ratio', 'H^3/E^2_ratio', 
            'KAMM', 'KAEM', 'KAPM', 'KAMM_RATIO', 'KAMM_NORMPROD']
x = StandardScaler().fit_transform(data[features])
# Apply PCA --> reducing the dimensionality for visualization purposes
pca = PCA(n_components=2)
# Replace NaN values with the mean of each column
x = np.nan_to_num(x, nan=np.nanmean(x, axis=0))
principal_components = pca.fit_transform(x)
pc_df = pd.DataFrame(data=principal_components, columns=['PC1', 'PC2'])
# Add cluster labels to the PCA dataframe
if method == 'KMeans':
    kmeans = KMeans(n_clusters=optimal_k, random_state=42)
    pc_df['Cluster'] = kmeans.fit_predict(data[['HARDNESS_GPa', 'MODULUS_GPa']].fillna(method='ffill').fillna(method='bfill'))
elif method == 'GMM':
    gmm = GaussianMixture(n_components=optimal_k, random_state=42)
    pc_df['Cluster'] = gmm.fit_predict(data[['HARDNESS_GPa', 'MODULUS_GPa']].fillna(method='ffill').fillna(method='bfill'))
elif method == 'DBSCAN':
    dbscan = DBSCAN(eps=0.5, min_samples=50)
    pc_df['Cluster'] = dbscan.fit_predict(data[['HARDNESS_GPa', 'MODULUS_GPa']].fillna(method='ffill').fillna(method='bfill'))
    # Replace -1 with a positive value (e.g., max cluster label + 1)
    new_cluster_label = pc_df['Cluster'].max() + 1
    pc_df['Cluster'] = pc_df['Cluster'].replace(-1, new_cluster_label)
    # Calculate the number of clusters
    optimal_k = len(set(pc_df['Cluster']))

print(pc_df.head())

# Define colors for clusters
colors = sns.color_palette('tab10', n_colors=optimal_k)
cmap = {i: colors[i] for i in range(optimal_k)}

# Plot PCA results
plot_clustered_data(pc_df, 'PC1', 'PC2', 'Cluster',        
                    colors, result_dir, xDim, yDim, 
                    'PCA of Hardness and Modulus', 'Principal Component 1', 'Principal Component 2')

# Check for duplicates in (X Position_µm, Y Position_µm)
print(data[data.duplicated(subset=['X Position_µm', 'Y Position_µm'], keep=False)])
duplicates = data.duplicated(subset=['X Position_µm', 'Y Position_µm'], keep=False)
if duplicates.any():
    print("Found duplicates in (X Position_µm, Y Position_µm). Resolving...")

    # Option 1: Aggregate duplicates by taking the mean of the Cluster values
    data = data.groupby(['X Position_µm', 'Y Position_µm'], as_index=False).mean()

    # Option 2: Drop duplicate rows (if aggregation is not appropriate)
    # data = data.drop_duplicates(subset=['X Position_µm', 'Y Position_µm'])

# Plot the corresponding phase map
plot_pixel_map(data['X Position_µm'], data['Y Position_µm'], pc_df['Cluster'], 
               title='Phase Map from PCA Clusters', xlabel='X Position (µm)', ylabel='Y Position (µm)',
               xDim=xDim, yDim=yDim,
               cluster_colors=cmap, save_path=result_dir / 'spatial_clusters_pca.png')
# Out:
#         PC1       PC2  Cluster
# 0 -1.080382 -0.666738        2
# 1 -1.210664 -0.590503        2
# 2 -1.307561 -0.506191        2
# 3 -1.319249 -0.225969        2
# 4 -0.723211  0.835536        2
# C:\Users\dmercier\AppData\Local\Temp\ipykernel_29112\1827907693.py:19: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   pc_df['Cluster'] = kmeans.fit_predict(data[['HARDNESS_GPa', 'MODULUS_GPa']].fillna(method='ffill').fillna(method='bfill'))
# c:\Users\dmercier\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# Clustered data plot saved to Results\3D_Clustering\Ni_SiC\PCA_of_Hardness_and_Modulus.png
# Empty DataFrame
# Columns: [X Position_µm, Y Position_µm, MODULUS_GPa, HARDNESS_GPa, H/E_ratio, H^3/E^2_ratio, KAMM, KAEM, KAPM, KAMM_RATIO, KAMM_NORMPROD]
# Index: []
# Pixel map plot saved to Results\3D_Clustering\Ni_SiC\spatial_clusters_pca.png

# %% [markdown]
# ### Clustering score

# %%
from sklearn.metrics import silhouette_score, calinski_harabasz_score, davies_bouldin_score

# Function to evaluate clustering
def evaluate_clustering(data, features, cluster_col):
    # Ensure there is more than one cluster
    if len(data[cluster_col].unique()) > 1:
        # Calculate Silhouette Score
        silhouette = silhouette_score(data[features], data[cluster_col])
        print(f"Silhouette Score: {silhouette:.2f}")
        if silhouette > 0.7:
            print("The clustering is excellent with well-separated clusters.")
        elif 0.5 < silhouette <= 0.7:
            print("The clustering is good, but there might be some overlap between clusters.")
        elif 0.2 < silhouette <= 0.5:
            print("The clustering is average, with significant overlap or poorly defined clusters.")
        else:
            print("The clustering is poor, with no clear separation between clusters.")
        
        # Calculate Calinski-Harabasz Index
        calinski = calinski_harabasz_score(data[features], data[cluster_col])
        print(f"Calinski-Harabasz Index: {calinski:.2f}")
        if calinski > 500:
            print("The clustering is excellent with well-separated and dense clusters.")
        elif 200 < calinski <= 500:
            print("The clustering is good, but there might be some overlap between clusters.")
        elif 50 < calinski <= 200:
            print("The clustering is average, with significant overlap or poorly defined clusters.")
        else:
            print("The clustering is poor, with high within-cluster variance or no clear separation.")

        # Calculate Davis-Bouldin Index
        davies_bouldin = davies_bouldin_score(data[features], data[cluster_col])
        print(f"Davies-Bouldin Index: {davies_bouldin:.2f}")
        if davies_bouldin < 0.5:
            print("The clustering is excellent with well-separated clusters.")
        elif 0.5 <= davies_bouldin < 1.0:
            print("The clustering is good, but there might be some overlap between clusters.")
        elif 1.0 <= davies_bouldin < 2.0:
            print("The clustering is average, with significant overlap or poorly defined clusters.")
        else:
            print("The clustering is poor, with no clear separation between clusters.")

    else:
        print("Clustering evaluation cannot be performed with only one cluster.")

print("Evaluate score for the PCA-based clustering:")
evaluate_clustering(pc_df, ['PC1', 'PC2'], 'Cluster')
# Out:
# Evaluate score for the PCA-based clustering:
# Silhouette Score: 0.35
# The clustering is average, with significant overlap or poorly defined clusters.
# Calinski-Harabasz Index: 1441.39
# The clustering is excellent with well-separated and dense clusters.
# Davies-Bouldin Index: 1.18
# The clustering is average, with significant overlap or poorly defined clusters.

# %% [markdown]
# ### All plots

# %%
# Define colors for clusters
colors = sns.color_palette('tab10', n_colors=optimal_k)
cluster_cmap = ListedColormap(colors)

# Add Cluster information to the original data
data['Cluster'] = pc_df['Cluster']

# Pivot data for pixelized map (handle duplicates by aggregating with pivot_table)
grid_data = data.pivot_table(
    index='Y Position_µm',
    columns='X Position_µm',
    values='Cluster',
    aggfunc='mean'  # You can use 'mean', 'median', or another aggregation function
)
grid_data = grid_data.sort_index(ascending=False)  # Ensure proper orientation

# Create the 2x2 plot
fig, axes = plt.subplots(2, 2, figsize=(3*xDim, 4*yDim))

# Top Left: PDF for Hardness
sns.kdeplot(data['HARDNESS_GPa'], ax=axes[0, 0], fill=True, color='gray')
axes[0, 0].set_title('PDF for Hardness')
axes[0, 0].set_xlabel('Hardness (GPa)')
axes[0, 0].set_ylabel('Density')
# Add Deconvolution with peaks with same colors as corresponding clusters
n_componentsVal = optimal_k  # Use the optimal number of clusters determined earlier
from sklearn.mixture import GaussianMixture
gmm = GaussianMixture(n_components=n_componentsVal, random_state=0)
gmm.fit(data[['HARDNESS_GPa']].dropna())
x = np.linspace(data['HARDNESS_GPa'].min(), data['HARDNESS_GPa'].max(), 1000).reshape(-1, 1)
logprob = gmm.score_samples(x)
responsibilities = gmm.predict_proba(x)
pdf = np.exp(logprob)
for i in range(n_componentsVal):
    axes[0, 0].plot(x, responsibilities[:, i] * pdf, label=f'Component {i+1}', color=colors[i])
axes[0, 0].plot(x, pdf, '-k', label='GMM Total')
axes[0, 0].legend()

# Top Right: Pixelized Map
im = axes[0, 1].imshow(grid_data, cmap=cluster_cmap, aspect='equal', interpolation='none')
axes[0, 1].set_title('Pixelized Map')
axes[0, 1].set_xlabel('X Position (µm)')
axes[0, 1].set_ylabel('Y Position (µm)')

# Create discrete legend handles for clusters
unique_clusters = np.unique(grid_data[~np.isnan(grid_data)])  # Exclude NaN values
handles = [
    plt.Line2D(
        [0], [0], 
        marker='s', 
        color=cluster_cmap(cluster / len(unique_clusters)), 
        linestyle='', 
        markersize=10, 
        label=f'Cluster {int(cluster)}'
    ) 
    for cluster in unique_clusters if not np.isnan(cluster)  # Ensure cluster is not NaN
]

# Add the discrete legend
axes[0, 1].legend(handles=handles, title="Clusters", bbox_to_anchor=(1.05, 1), loc='upper left')

# Bottom Right: PDF for Elastic Modulus rotated 90°
sns.kdeplot(data['MODULUS_GPa'], ax=axes[1, 1], fill=True, color='gray', vertical=True)
axes[1, 1].set_title('PDF for Elastic Modulus')
axes[1, 1].set_xlabel('Density')
axes[1, 1].set_ylabel('Elastic Modulus (GPa)')
# Add Deconvolution with peaks with same colors as corresponding clusters
gmm = GaussianMixture(n_components=n_componentsVal, random_state=0)
gmm.fit(data[['MODULUS_GPa']].dropna())
x = np.linspace(data['MODULUS_GPa'].min(), data['MODULUS_GPa'].max(), 1000).reshape(-1, 1)
logprob = gmm.score_samples(x)
responsibilities = gmm.predict_proba(x)
pdf = np.exp(logprob)
for i in range(n_componentsVal):
    axes[1, 1].plot(responsibilities[:, i] * pdf, x, label=f'Component {i+1}', color=colors[i])
axes[1, 1].plot(pdf, x, '-k', label='GMM Total')
axes[1, 1].legend()

# Bottom Left: Elastic Modulus vs Hardness with same axis scale than PDFs plots
sns.scatterplot(y='MODULUS_GPa', x='HARDNESS_GPa', data=data, ax=axes[1, 0], hue='Cluster', palette=colors, legend=False)
axes[1, 0].set_title('Elastic Modulus vs Hardness')
axes[1, 0].set_ylabel('Elastic Modulus (GPa)')
axes[1, 0].set_xlabel('Hardness (GPa)')
axes[1, 0].set_xlim(axes[0, 0].get_xlim())
axes[1, 0].set_ylim(axes[1, 1].get_ylim())
axes[1, 0].legend(title='Clusters')

# Adjust layout
plt.tight_layout()
plt.show()
# Out:
# c:\Users\dmercier\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\dmercier\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but GaussianMixture was fitted with feature names
#   warnings.warn(
# c:\Users\dmercier\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but GaussianMixture was fitted with feature names
#   warnings.warn(
# C:\Users\dmercier\AppData\Local\Temp\ipykernel_29112\3883552768.py:63: UserWarning:
#
# The `vertical` parameter is deprecated; assigning data to `y`.
# This will become an error in seaborn v0.13.0; please update your code.
#
#   sns.kdeplot(data['MODULUS_GPa'], ax=axes[1, 1], fill=True, color='gray', vertical=True)
# c:\Users\dmercier\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\dmercier\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but GaussianMixture was fitted with feature names
#   warnings.warn(
# c:\Users\dmercier\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but GaussianMixture was fitted with feature names
#   warnings.warn(
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
